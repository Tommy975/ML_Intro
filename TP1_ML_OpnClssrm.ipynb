# %% [markdown]
# <a href="https://colab.research.google.com/github/Tommy975/ML_Intro_OpnClssrm/blob/main/TP1_ML_OpnClssrm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# On charge le dataset dans un pandas dataframe
# 1. on store l'url de notre dataset dans une variable
# 2. on store notre dataset dans un pd df a l'aide de la méthode read_csv() de 
# la librairie pandas

url = "https://raw.githubusercontent.com/Tommy975/ML_DL/main/Datasets/house_data.csv?token=AFLKTMRULAZEVYKAG4NQILTADNBUG"
df1 = pd.read_csv(url)

# %%
plt.plot(df1['surface'],df1['price'], 'x', markersize=4)
plt.show()

# %%
plt.plot(df1['arrondissement'], df1['price'], 'x', markersize=4)

# %%
df2 = df1[df1['price'] < 10000]

# %%
plt.plot(df2['surface'],df2['price'], 'x', markersize=4)

# %%
plt.plot(df2['arrondissement'],df2['price'], 'x', markersize=4)

# %%
print(df1)
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 822    850    35.00            10.0
# 823    700    10.00            10.0
# 824   1280    34.00            10.0
# 825   1545    65.00            10.0
# 826   1000    21.43            10.0
#
# [827 rows x 3 columns]

# %%
df1 = df1.reset_index()

# %%
X,Y = df2[['surface','arrondissement']], df2[['price']]


X,Y = X.values,Y.values


print("Shape de X : "+str(X.shape)) #Nous avons ici un array 2 dimensions.
print("Shape de Y : "+str(Y.shape)) #Nous avons ici un array d'une seule dimension.
# Out:
# Shape de X : (818, 2)
# Shape de Y : (818, 1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=.20)

# regr = linear_model.LinearRegression()
# regr.fit(X_train, Y_train)
# X_test
# # predicted = regr.predict(X_test)

# %%
regr = LinearRegression().fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-a1442f5d68a4> in <module>()
# ----> 1 regr = LinearRegression().fit(X_train,Y_train)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     490         n_jobs_ = self.n_jobs
#     491         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 492                          y_numeric=True, multi_output=True)
#     493
#     494         if sample_weight is not None:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# --> 755                     estimator=estimator)
#     756     if multi_output:
#     757         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     576         if force_all_finite:
#     577             _assert_all_finite(array,
# --> 578                                allow_nan=force_all_finite == 'allow-nan')
#     579
#     580     if ensure_min_samples > 0:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      58                     msg_err.format
#      59                     (type_err,
# ---> 60                      msg_dtype if msg_dtype is not None else X.dtype)
#      61             )
#      62     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
X_train
# Out:
# array([[ 72.  ,   4.  ],
#        [ 23.4 ,   1.  ],
#        [ 24.  ,   1.  ],
#        ...,
#        [ 21.  ,  10.  ],
#        [183.69,   4.  ],
#        [ 56.55,  10.  ]])

# %%
Y_train
# Out:
# array([[ 1800],
#        [ 1003],
#        [  855],
#        [ 1400],
#        [ 1400],
#        [ 1100],
#        [  750],
#        [15000],
#        [  938],
#        [ 1000],
#        [ 1990],
#        [ 1100],
#        [ 3650],
#        [  956],
#        [ 1300],
#        [ 1220],
#        [ 2000],
#        [ 3480],
#        [ 2300],
#        [ 1220],
#        [ 1180],
#        [ 1800],
#        [ 1890],
#        [  850],
#        [ 1567],
#        [ 1150],
#        [  940],
#        [ 2300],
#        [ 1333],
#        [ 1850],
#        [ 1000],
#        [ 3060],
#        [ 1800],
#        [ 1100],
#        [ 1820],
#        [ 1000],
#        [ 1166],
#        [ 1100],
#        [ 1380],
#        [  950],
#        [ 2200],
#        [ 1800],
#        [ 1850],
#        [ 1355],
#        [ 6300],
#        [  800],
#        [ 1000],
#        [  825],
#        [ 2650],
#        [ 1166],
#        [10500],
#        [ 3587],
#        [ 1300],
#        [ 1640],
#        [ 2941],
#        [ 3900],
#        [  788],
#        [ 2470],
#        [  799],
#        [ 1120],
#        [ 2371],
#        [ 2250],
#        [  668],
#        [ 1550],
#        [ 1427],
#        [  899],
#        [ 2250],
#        [  835],
#        [ 1460],
#        [ 1101],
#        [ 2950],
#        [  888],
#        [  730],
#        [ 1000],
#        [ 4620],
#        [ 1574],
#        [  700],
#        [ 1100],
#        [ 1300],
#        [ 2750],
#        [ 1450],
#        [ 1480],
#        [ 1885],
#        [  825],
#        [  799],
#        [ 2480],
#        [ 2700],
#        [ 2100],
#        [  754],
#        [ 1355],
#        [ 1640],
#        [ 1750],
#        [ 2485],
#        [ 1220],
#        [ 1220],
#        [ 1200],
#        [ 1690],
#        [10000],
#        [ 2020],
#        [ 2000],
#        [ 3000],
#        [ 4705],
#        [ 1200],
#        [ 5000],
#        [ 1700],
#        [ 2175],
#        [ 2000],
#        [  925],
#        [ 2300],
#        [  930],
#        [ 2623],
#        [ 2450],
#        [ 3400],
#        [ 1900],
#        [ 2695],
#        [  788],
#        [  854],
#        [ 2850],
#        [ 3750],
#        [ 2400],
#        [ 2320],
#        [  734],
#        [ 2020],
#        [ 1900],
#        [ 2107],
#        [ 1835],
#        [ 1750],
#        [  981],
#        [ 3000],
#        [ 1900],
#        [  750],
#        [  645],
#        [ 1200],
#        [ 1400],
#        [ 2010],
#        [ 1350],
#        [  710],
#        [ 1329],
#        [ 2650],
#        [ 1050],
#        [ 1200],
#        [ 3300],
#        [ 1500],
#        [  780],
#        [ 2500],
#        [  820],
#        [ 1218],
#        [ 2800],
#        [ 2748],
#        [ 1500],
#        [ 1423],
#        [  820],
#        [ 2750],
#        [ 5950],
#        [ 1860],
#        [ 1050],
#        [ 1624],
#        [ 1500],
#        [  790],
#        [ 2136],
#        [ 1150],
#        [  900],
#        [ 1875],
#        [ 2807],
#        [ 3200],
#        [ 4100],
#        [ 1016],
#        [  990],
#        [ 2367],
#        [  950],
#        [ 2375],
#        [ 1200],
#        [ 2445],
#        [ 1280],
#        [  958],
#        [  899],
#        [ 1840],
#        [ 2475],
#        [  790],
#        [ 1578],
#        [  747],
#        [ 2900],
#        [ 3490],
#        [ 1397],
#        [  930],
#        [ 2500],
#        [  950],
#        [ 1630],
#        [ 5100],
#        [ 1835],
#        [ 1700],
#        [ 1850],
#        [  996],
#        [ 2661],
#        [ 3200],
#        [ 1535],
#        [ 1400],
#        [ 2010],
#        [  747],
#        [14300],
#        [  784],
#        [ 6800],
#        [  754],
#        [ 2000],
#        [ 3900],
#        [ 5000],
#        [ 5600],
#        [  780],
#        [ 3700],
#        [ 2400],
#        [ 1253],
#        [ 1540],
#        [  450],
#        [ 3000],
#        [  770],
#        [ 3000],
#        [ 1400],
#        [ 1200],
#        [ 3500],
#        [ 1100],
#        [  750],
#        [ 7500],
#        [ 4722],
#        [ 3320],
#        [ 1560],
#        [ 2500],
#        [ 1520],
#        [  754],
#        [ 2800],
#        [  830],
#        [  750],
#        [ 2700],
#        [ 1100],
#        [ 3680],
#        [ 3020],
#        [ 2995],
#        [ 2595],
#        [ 2700],
#        [  795],
#        [ 4807],
#        [  568],
#        [ 1900],
#        [ 1920],
#        [ 3200],
#        [ 1890],
#        [ 2180],
#        [ 2500],
#        [ 1610],
#        [ 2212],
#        [ 2155],
#        [ 3000],
#        [ 2999],
#        [ 1550],
#        [  530],
#        [  800],
#        [  750],
#        [ 1423],
#        [ 2300],
#        [ 2325],
#        [ 1704],
#        [ 5000],
#        [ 1750],
#        [  900],
#        [ 1488],
#        [ 1295],
#        [ 1150],
#        [  390],
#        [ 2324],
#        [ 1400],
#        [ 1900],
#        [ 1995],
#        [  712],
#        [ 1555],
#        [ 1600],
#        [ 3500],
#        [  542],
#        [ 1217],
#        [ 3500],
#        [ 3000],
#        [ 1762],
#        [ 2310],
#        [ 1600],
#        [  932],
#        [ 1375],
#        [ 1200],
#        [ 1000],
#        [ 2614],
#        [  980],
#        [ 1250],
#        [  930],
#        [ 1350],
#        [ 1954],
#        [ 3000],
#        [ 1995],
#        [ 3000],
#        [ 1300],
#        [ 1667],
#        [ 1820],
#        [ 1409],
#        [ 3665],
#        [ 1280],
#        [ 2536],
#        [  498],
#        [ 1250],
#        [ 3234],
#        [ 1246],
#        [ 1140],
#        [ 1195],
#        [ 1550],
#        [ 1500],
#        [ 2990],
#        [ 3750],
#        [ 1950],
#        [  996],
#        [  650],
#        [ 7450],
#        [ 1450],
#        [ 2240],
#        [ 1990],
#        [  799],
#        [  915],
#        [ 1850],
#        [ 1605],
#        [ 2650],
#        [ 5500],
#        [ 1042],
#        [  675],
#        [  850],
#        [ 1900],
#        [ 1700],
#        [ 1360],
#        [ 2955],
#        [ 1290],
#        [ 1308],
#        [ 3350],
#        [ 1580],
#        [ 2044],
#        [  655],
#        [ 1118],
#        [ 1360],
#        [ 1574],
#        [ 2102],
#        [ 2500],
#        [  920],
#        [ 2290],
#        [ 2500],
#        [ 2130],
#        [ 1260],
#        [ 2500],
#        [  840],
#        [ 2300],
#        [ 1690],
#        [ 3480],
#        [ 1420],
#        [ 2282],
#        [  910],
#        [  700],
#        [ 1800],
#        [ 1890],
#        [ 2090],
#        [ 1300],
#        [ 1137],
#        [  850],
#        [ 1230],
#        [  754],
#        [ 1185],
#        [ 2100],
#        [ 1490],
#        [  550],
#        [15000],
#        [ 2000],
#        [ 2250],
#        [ 1800],
#        [ 3500],
#        [ 1375],
#        [  603],
#        [  830],
#        [ 3000],
#        [ 1111],
#        [ 1400],
#        [  758],
#        [ 1700],
#        [ 3700],
#        [  945],
#        [ 2200],
#        [ 4500],
#        [ 2100],
#        [ 4000],
#        [ 1700],
#        [ 5600],
#        [ 1350],
#        [  758],
#        [ 1250],
#        [ 1550],
#        [ 4000],
#        [ 1050],
#        [ 2500],
#        [ 2300],
#        [ 1950],
#        [ 2358],
#        [ 1300],
#        [ 1235],
#        [ 1700],
#        [ 2324],
#        [ 1390],
#        [ 1159],
#        [ 3000],
#        [ 1921],
#        [ 3200],
#        [ 3770],
#        [  895],
#        [ 1910],
#        [  899],
#        [ 4600],
#        [ 2780],
#        [  800],
#        [ 1988],
#        [  519],
#        [ 4500],
#        [ 1850],
#        [ 1100],
#        [ 5000],
#        [  750],
#        [ 2350],
#        [  750],
#        [ 1960],
#        [ 1700],
#        [ 2200],
#        [ 1275],
#        [  990],
#        [ 4705],
#        [  566],
#        [ 1640],
#        [ 2100],
#        [ 1550],
#        [  744],
#        [ 1350],
#        [ 1335],
#        [21000],
#        [ 4722],
#        [ 3480],
#        [  799],
#        [ 1290],
#        [ 1048],
#        [ 4138],
#        [ 1250],
#        [ 1945],
#        [  402],
#        [ 1750],
#        [ 1462],
#        [ 1166],
#        [ 2264],
#        [ 1700],
#        [ 2700],
#        [ 1750],
#        [  890],
#        [  790],
#        [ 1590],
#        [  710],
#        [  799],
#        [ 1000],
#        [  620],
#        [ 1166],
#        [ 1400],
#        [ 3000],
#        [  684],
#        [ 2280],
#        [ 1300],
#        [ 2482],
#        [ 1590],
#        [ 2550],
#        [ 4500],
#        [  899],
#        [ 3000],
#        [  834],
#        [ 1640],
#        [ 1400],
#        [ 2300],
#        [ 1300],
#        [ 1732],
#        [ 3200],
#        [ 1000],
#        [ 1050],
#        [  650],
#        [ 2367],
#        [  990],
#        [ 2200],
#        [  940],
#        [ 1850],
#        [ 3000],
#        [ 2800],
#        [  800],
#        [ 2100],
#        [ 2500],
#        [ 1375],
#        [ 1415],
#        [ 1000],
#        [  603],
#        [  860],
#        [ 2000],
#        [ 1600],
#        [  995],
#        [ 2445],
#        [ 1750],
#        [  990],
#        [ 2675],
#        [ 4480],
#        [  747],
#        [ 7450],
#        [ 4050],
#        [  795],
#        [ 1400],
#        [  900],
#        [ 1295],
#        [  528],
#        [ 1200],
#        [ 2100],
#        [  969],
#        [  598],
#        [  758],
#        [ 1835],
#        [  799],
#        [  800],
#        [ 2301],
#        [ 5000],
#        [  850],
#        [  990],
#        [ 1087],
#        [ 1000],
#        [ 2315],
#        [ 5500],
#        [ 1215],
#        [ 1419],
#        [ 1664],
#        [ 6500],
#        [ 1010],
#        [ 2800],
#        [ 1950],
#        [ 1140],
#        [ 1400],
#        [ 1250],
#        [15600],
#        [  875],
#        [  600],
#        [ 2450],
#        [ 4000],
#        [ 1100],
#        [ 1355],
#        [ 1800],
#        [ 2614],
#        [  795],
#        [ 2600],
#        [ 1200],
#        [ 2150],
#        [ 2200],
#        [ 1700],
#        [ 2900],
#        [ 2614],
#        [ 3250],
#        [  690],
#        [ 1100],
#        [ 1740],
#        [ 2050],
#        [ 2000],
#        [  899],
#        [ 1165],
#        [  860],
#        [ 2500],
#        [ 2008],
#        [ 1500],
#        [ 1750],
#        [ 1177],
#        [ 2156],
#        [ 3650],
#        [ 3660],
#        [  700],
#        [ 4340],
#        [ 1235]])
